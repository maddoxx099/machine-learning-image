# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
  
tokenizer = AutoTokenizer.from_pretrained("opus-mt-en-hi")

model = AutoModelForSeq2SeqLM.from_pretrained("opus-mt-en-hi")

# %%
def translator(text):
  # function to translate english text to hindi
  input_ids = tokenizer.encode(text, return_tensors="pt", padding=True)
  outputs = model.generate(input_ids)
  decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
  
  return decoded_text

# %%
texts = open('test.txt')

# %%
for text in texts:
  print("English Text: ", text)
  print("Hindi Translation: ", translator(text))
  print("*"*50,"\n")
# Out:
# English Text:  A black box in your car?
# Hindi Translation:  अपनी कार में एक ब्लैक बॉक्स?
# **************************************************
#
# English Text:  As America's road planners struggle to find the cash to mend a crumbling highway system, many are beginning to see a solution in a little black box that fits neatly by the dashboard of your car.
# Hindi Translation:  के रूप में अमेरिका के सड़क योजनार एक टूटी हुई सड़क प्रणाली को सुधारने के लिए नकदी को खोजने के लिए संघर्ष कर रहे हैं, कई एक छोटे से काले बॉक्स में एक समाधान देखने के लिए शुरू कर रहे हैं कि अपनी कार के माध्यम से फिट.
# **************************************************
#
# English Text:  The devices, which track every mile a motorist drives and transmit that information to bureaucrats, are at the center of a controversial attempt in Washington and state planning offices to overhaul the outdated system for funding America's major roads.
# Hindi Translation:  ये उपकरण, जो हर मील का ट्रैक करते हैं एक मोटर ड्राइव और ट्रांसमीटर के लिए जानकारी भेजने वाले हैं, एक विवादपूर्ण प्रयास के केंद्र में कर रहे हैं वॉशिंगटन और राज्य योजना कार्यालयों के लिए अमेरिका के मुख्य सड़कों पर पैसा जमा करने के लिए।
# **************************************************
#
# English Text:  The usually dull arena of highway planning has suddenly spawned intense debate and colorful alliances.
# Hindi Translation:  आम तौर पर सड़क योजना के ठंडे रंग में बहस और रंग - बिरंगी ब्याह की वजह से अचानक बहस छिड़ जाती है ।
# **************************************************
#
# English Text:  Libertarians have joined environmental groups in lobbying to allow government to use the little boxes to keep track of the miles you drive, and possibly where you drive them - then use the information to draw up a tax bill.
# Hindi Translation:  कुछ देशों में ऐसे भी लोग हैं जो एक - दूसरे को सहयोग देने के लिए सरकार का इस्तेमाल करते हैं ।
# **************************************************
#
# English Text:  The tea party is aghast.
# Hindi Translation:  चाय पार्टी कम हो गई है.
# **************************************************
#
# English Text:  The American Civil Liberties Union is deeply concerned, too, raising a variety of privacy issues.
# Hindi Translation:  अमरीकी नागरिक संघ को भी अलग - अलग निजी मामलों की चिंता रहती है ।
# **************************************************
#
# English Text:  And while Congress can't agree on whether to proceed, several states are not waiting.
# Hindi Translation:  और जबकि कांग्रेस आगे बढ़ने पर सहमत नहीं हो सकता है, कई राज्य इंतजार नहीं कर रहे हैं.
# **************************************************
#
# English Text:  They are exploring how, over the next decade, they can move to a system in which drivers pay per mile of road they roll over.
# Hindi Translation:  वे कल्पना कर रहे हैं कि अगले दस सालों के दौरान, वे एक ऐसी व्यवस्था में जा सकते हैं जिसमें ड्राइवर हर मील की दूरी पर गाड़ी चलाते हैं ।
# **************************************************
#
# English Text:  Thousands of motorists have already taken the black boxes, some of which have GPS monitoring, for a test drive.
# Hindi Translation:  हज़ारों मोटर - चालकों ने पहले ही ब्लैक बक्से ले लिए हैं, जिनमें से कुछ के पास जीपीएस निगरानी है, एक परीक्षण ड्राइव के लिए.
# **************************************************
#
# English Text:  This really is a must for our nation.
# Hindi Translation:  यह वास्तव में हमारी जाति के लिए एक होना चाहिए.
# **************************************************
#
# English Text:  "It is not a matter of something we might choose to do," said Hasan Ikhrata, executive director of the Southern California Assn. of Governments, which is planning for the state to start tracking miles driven by every California motorist by 2025.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 for text in texts:
#       2   print("English Text: ", text)
# ----> 3   print("Hindi Translation: ", translator(text))
#       4   print("*"*50,"\n")
#
# Cell In[3], line 4, in translator(text)
#       1 def translator(text):
#       2   # function to translate english text to hindi
#       3   input_ids = tokenizer.encode(text, return_tensors="pt", padding=True)
# ----> 4   outputs = model.generate(input_ids)
#       5   decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
#       7   return decoded_text
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\generation\utils.py:1752, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1745     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1746         input_ids=input_ids,
#    1747         expand_size=generation_config.num_beams,
#    1748         is_encoder_decoder=self.config.is_encoder_decoder,
#    1749         **model_kwargs,
#    1750     )
#    1751     # 13. run beam search
# -> 1752     return self.beam_search(
#    1753         input_ids,
#    1754         beam_scorer,
#    1755         logits_processor=logits_processor,
#    1756         stopping_criteria=stopping_criteria,
#    1757         pad_token_id=generation_config.pad_token_id,
#    1758         eos_token_id=generation_config.eos_token_id,
#    1759         output_scores=generation_config.output_scores,
#    1760         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1761         synced_gpus=synced_gpus,
#    1762         **model_kwargs,
#    1763     )
#    1765 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1766     # 11. prepare logits warper
#    1767     logits_warper = self._get_logits_warper(generation_config)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\generation\utils.py:3091, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    3087         break
#    3089 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 3091 outputs = self(
#    3092     **model_inputs,
#    3093     return_dict=True,
#    3094     output_attentions=output_attentions,
#    3095     output_hidden_states=output_hidden_states,
#    3096 )
#    3098 if synced_gpus and this_peer_finished:
#    3099     cur_len = cur_len + 1
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\models\marian\modeling_marian.py:1402, in MarianMTModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1397     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1398         decoder_input_ids = shift_tokens_right(
#    1399             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1400         )
# -> 1402 outputs = self.model(
#    1403     input_ids,
#    1404     attention_mask=attention_mask,
#    1405     decoder_input_ids=decoder_input_ids,
#    1406     encoder_outputs=encoder_outputs,
#    1407     decoder_attention_mask=decoder_attention_mask,
#    1408     head_mask=head_mask,
#    1409     decoder_head_mask=decoder_head_mask,
#    1410     cross_attn_head_mask=cross_attn_head_mask,
#    1411     past_key_values=past_key_values,
#    1412     inputs_embeds=inputs_embeds,
#    1413     decoder_inputs_embeds=decoder_inputs_embeds,
#    1414     use_cache=use_cache,
#    1415     output_attentions=output_attentions,
#    1416     output_hidden_states=output_hidden_states,
#    1417     return_dict=return_dict,
#    1418 )
#    1419 lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#    1421 masked_lm_loss = None
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\models\marian\modeling_marian.py:1203, in MarianModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1196     encoder_outputs = BaseModelOutput(
#    1197         last_hidden_state=encoder_outputs[0],
#    1198         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1199         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1200     )
#    1202 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1203 decoder_outputs = self.decoder(
#    1204     input_ids=decoder_input_ids,
#    1205     attention_mask=decoder_attention_mask,
#    1206     encoder_hidden_states=encoder_outputs[0],
#    1207     encoder_attention_mask=attention_mask,
#    1208     head_mask=decoder_head_mask,
#    1209     cross_attn_head_mask=cross_attn_head_mask,
#    1210     past_key_values=past_key_values,
#    1211     inputs_embeds=decoder_inputs_embeds,
#    1212     use_cache=use_cache,
#    1213     output_attentions=output_attentions,
#    1214     output_hidden_states=output_hidden_states,
#    1215     return_dict=return_dict,
#    1216 )
#    1218 if not return_dict:
#    1219     return decoder_outputs + encoder_outputs
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\models\marian\modeling_marian.py:1003, in MarianDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     990     layer_outputs = self._gradient_checkpointing_func(
#     991         decoder_layer.__call__,
#     992         hidden_states,
#    (...)
#    1000         use_cache,
#    1001     )
#    1002 else:
# -> 1003     layer_outputs = decoder_layer(
#    1004         hidden_states,
#    1005         attention_mask=attention_mask,
#    1006         encoder_hidden_states=encoder_hidden_states,
#    1007         encoder_attention_mask=encoder_attention_mask,
#    1008         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1009         cross_attn_layer_head_mask=(
#    1010             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1011         ),
#    1012         past_key_value=past_key_value,
#    1013         output_attentions=output_attentions,
#    1014         use_cache=use_cache,
#    1015     )
#    1016 hidden_states = layer_outputs[0]
#    1018 if use_cache:
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\models\marian\modeling_marian.py:432, in MarianDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     430 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     431 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 432 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     433     hidden_states=hidden_states,
#     434     key_value_states=encoder_hidden_states,
#     435     attention_mask=encoder_attention_mask,
#     436     layer_head_mask=cross_attn_layer_head_mask,
#     437     past_key_value=cross_attn_past_key_value,
#     438     output_attentions=output_attentions,
#     439 )
#     440 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     441 hidden_states = residual + hidden_states
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\NLP SIH FINAL\venv\lib\site-packages\transformers\models\marian\modeling_marian.py:259, in MarianAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     253     raise ValueError(
#     254         f"`attn_output` should be of size {(bsz * self.num_heads, tgt_len, self.head_dim)}, but is"
#     255         f" {attn_output.size()}"
#     256     )
#     258 attn_output = attn_output.view(bsz, self.num_heads, tgt_len, self.head_dim)
# --> 259 attn_output = attn_output.transpose(1, 2)
#     261 # Use the `embed_dim` from the config (stored in the class) rather than `hidden_state` because `attn_output` can be
#     262 # partitioned across GPUs when using tensor-parallelism.
#     263 attn_output = attn_output.reshape(bsz, tgt_len, self.embed_dim)
#
# KeyboardInterrupt:
